# %%
import pandas as pd

favorite = pd.Series(['Winter', 'Summer', 'Spring', 'Summer', 'Summer', 'Fall', 'Fall', 'Summer', 'Spring', 'Spring'])
favorite
# Out:
# 0    Winter
# 1    Summer
# 2    Spring
# 3    Summer
# 4    Summer
# 5      Fall
# 6      Fall
# 7    Summer
# 8    Spring
# 9    Spring
# dtype: object

# %%
favorite.value_counts()
# Out:
# Summer    4
# Spring    3
# Fall      2
# Winter    1
# Name: count, dtype: int64

# %%
favorite.value_counts() / favorite.size
# Out:
# Summer    0.4
# Spring    0.3
# Fall      0.2
# Winter    0.1
# Name: count, dtype: float64

# %%
favorite.value_counts() / favorite.size
# Out:
# Summer    0.4
# Spring    0.3
# Fall      0.2
# Winter    0.1
# Name: count, dtype: float64

# %%
fd = favorite.value_counts()

type(fd)
# Out:
# pandas.core.series.Series

# %%
fd['Summer']
# Out:
# np.int64(4)

# %%
fd.iloc[2]
# Out:
# np.int64(2)

# %%
import matplotlib.pyplot as plt

fd.plot.bar(xlabel = 'Seasons', ylabel = 'Frequency',
            rot = 30, title='Favorite Seasons')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#Vertical Bar Chart
fd.plot.barh(xlabel = 'Seasons', ylabel = 'Frequency',
            rot = 30, title='Favorite Seasons')
plt.show()

# %%
fd.plot.pie()
plt.show()

# %%
fd.plot.pie(ylabel = '', autopct='%1.0f%%', title='Favorite Seasons')
plt.show()
