# %% [markdown]
# SCATTER PLOT

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('c:/Users/ACER/Documents/python_koica/data/mtcars.csv')
vars = ['mpg', 'disp', 'drat', 'wt']
pd.plotting.scatter_matrix(df[vars])
plt.show()
